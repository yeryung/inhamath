# %% [markdown]
# ## 데이터 불러오기

# %%
import pickle
from torch import from_numpy
from torch.utils import data

# get the data
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

rel_path = "/content/drive/MyDrive/Colab Notebooks/CIFAR-100/cifar-100-python/"
train_row_data = unpickle(rel_path+"train")
test_row_data = unpickle(rel_path+"test")
meta_row_data = unpickle(rel_path+"meta")

class CustomDataset():
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels
    
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, ind):
        return self.images[ind], self.labels[ind]

train_data = train_row_data[b'data'].reshape(50000, 3, 32, 32)
train_data = from_numpy(train_data).float()

test_data = test_row_data[b'data'].reshape(10000, 3, 32, 32)
test_data = from_numpy(test_data).float()

train_dataset = CustomDataset(train_data, train_row_data[b'fine_labels'])
test_dataset = CustomDataset(test_data, test_row_data[b'fine_labels'])

print("input data shape", train_data[0].shape)
print("train dataset size", len(train_dataset))
print("test data size", len(test_dataset))

#Data loader, dataset 을 pythorch 에서 사용하기 편한형태로 변환
batch_size = 32
train_loader = data.DataLoader(
    dataset = train_dataset,
    batch_size = batch_size,
    shuffle = True
)
test_loader = data.DataLoader(
    dataset = test_dataset,
    batch_size = batch_size,
    shuffle = False
)
# Out:
# input data shape torch.Size([3, 32, 32])
# train dataset size 50000
# test data size 10000

# %% [markdown]
# ## 모델

# %%
from torch import nn, optim, cuda
from torchvision import models

device = "cuda" if cuda.is_available() else "cpu" # device가 cuda 면 행렬연산에서 cpu 보다 빠른연산을 수행할 수 있는 gpu(그래픽카드)를 사용한다. 그렇지 않으면 그냥 cpu 를 사용한다
print(f"Training CIFAR on '{device}'\n{'='*44}") # cpu 를 사용하는지 gpu(cuda는 nvidia)를 사용하는지 출력해줌

model = models.efficientnet_b0(pretrained = True)
model.classifier[1] = nn.Linear(in_features=1280, out_features=100, bias=True)
model.to(device)

lossfunction = nn.CrossEntropyLoss()
optimiser = optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5) # stochastic gradient descent
# Out:
# Training CIFAR on 'cuda'
# ============================================

# %% [markdown]
# ## model summary

# %%
# from torchsummary import summary

# summary(model, (3, 32, 32))
# print(model)

# %% [markdown]
# ## train & test

# %%
import datetime
from torch import save
import os

path = "/content/drive/MyDrive/Colab Notebooks/CIFAR-100/"

serial = f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}"
weight_path = path+f"/backup/weight_{serial}"
os.makedirs(weight_path)

def train(epoch):
    model.train() # nn.Module.train method, train 과 test 를 구분, test 할 때는 modle.eval 을 호출한다
    for batch_ind, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimiser.zero_grad() # gradients 값을 0으로 초기화
        output = model(data)
        loss = lossfunction(output, target)
        loss.backward()
        optimiser.step()
        if batch_ind % 100 == 0:
            print('Train Epoch : {} | Batch Status : {}/{} ({:.0f}%) | Loss : {:.6f}'.format(
                epoch, 
                batch_ind*len(data), len(train_loader.dataset), 100. * batch_ind / len(train_loader),
                loss.item()
                ))

def test(epoch):
    model.eval() # nn.Module.eval method, train 과 test 를 구분, train 할 때는 model.train 을 호출한다
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = data.to(device), target.to(device) # gpu 에 tensor 들을 할당함(cpu가 아닌 gpu 로 계산하기 위함), 여기서 data, target 은 tensor 이다
        output = model(data)

        # sum up batch loss
        test_loss += lossfunction(output, target).item()

        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print("="*44)
    print(f"Test set: Average loss : {test_loss:.4f}, Accuracy : {correct}/{len(test_loader.dataset)}({100. * correct / len(test_loader.dataset):.0f}%)")


print(f"save files under {path}")
epoch = 30
for epoch in range(1, epoch+1):
    train(epoch)
    save(model.state_dict(), weight_path+f"/{epoch} {batch_size}")
    test(epoch)
# Out:
# save files under /content/drive/MyDrive/Colab Notebooks/CIFAR-100/
# Train Epoch : 1 | Batch Status : 0/50000 (0%) | Loss : 4.830959
# Train Epoch : 1 | Batch Status : 3200/50000 (6%) | Loss : 4.447664
# Train Epoch : 1 | Batch Status : 6400/50000 (13%) | Loss : 4.354732
# Train Epoch : 1 | Batch Status : 9600/50000 (19%) | Loss : 3.973842
# Train Epoch : 1 | Batch Status : 12800/50000 (26%) | Loss : 4.259941
# Train Epoch : 1 | Batch Status : 16000/50000 (32%) | Loss : 3.646838
# Train Epoch : 1 | Batch Status : 19200/50000 (38%) | Loss : 3.462451
# Train Epoch : 1 | Batch Status : 22400/50000 (45%) | Loss : 3.655944
# Train Epoch : 1 | Batch Status : 25600/50000 (51%) | Loss : 3.290753
# Train Epoch : 1 | Batch Status : 28800/50000 (58%) | Loss : 3.145368
# Train Epoch : 1 | Batch Status : 32000/50000 (64%) | Loss : 3.258646
# Train Epoch : 1 | Batch Status : 35200/50000 (70%) | Loss : 3.043272
# Train Epoch : 1 | Batch Status : 38400/50000 (77%) | Loss : 3.146784
# Train Epoch : 1 | Batch Status : 41600/50000 (83%) | Loss : 3.255227
# Train Epoch : 1 | Batch Status : 44800/50000 (90%) | Loss : 2.956807
# Train Epoch : 1 | Batch Status : 48000/50000 (96%) | Loss : 2.775077
# ============================================
# Test set: Average loss : 0.0830, Accuracy : 3276/10000(33%)
# Train Epoch : 2 | Batch Status : 0/50000 (0%) | Loss : 2.834016
# Train Epoch : 2 | Batch Status : 3200/50000 (6%) | Loss : 2.376019
# Train Epoch : 2 | Batch Status : 6400/50000 (13%) | Loss : 2.252819
# Train Epoch : 2 | Batch Status : 9600/50000 (19%) | Loss : 2.478588
# Train Epoch : 2 | Batch Status : 12800/50000 (26%) | Loss : 2.878754
# Train Epoch : 2 | Batch Status : 16000/50000 (32%) | Loss : 2.993599
# Train Epoch : 2 | Batch Status : 19200/50000 (38%) | Loss : 2.755200
# Train Epoch : 2 | Batch Status : 22400/50000 (45%) | Loss : 2.097827
# Train Epoch : 2 | Batch Status : 25600/50000 (51%) | Loss : 2.616075
# Train Epoch : 2 | Batch Status : 28800/50000 (58%) | Loss : 2.375824
# Train Epoch : 2 | Batch Status : 32000/50000 (64%) | Loss : 2.486366
# Train Epoch : 2 | Batch Status : 35200/50000 (70%) | Loss : 2.485415
# Train Epoch : 2 | Batch Status : 38400/50000 (77%) | Loss : 2.876986
# Train Epoch : 2 | Batch Status : 41600/50000 (83%) | Loss : 2.391371
# Train Epoch : 2 | Batch Status : 44800/50000 (90%) | Loss : 2.625218
# Train Epoch : 2 | Batch Status : 48000/50000 (96%) | Loss : 2.340981
# ============================================
# Test set: Average loss : 0.0674, Accuracy : 4277/10000(43%)
# Train Epoch : 3 | Batch Status : 0/50000 (0%) | Loss : 2.721898
# Train Epoch : 3 | Batch Status : 3200/50000 (6%) | Loss : 2.325350
# Train Epoch : 3 | Batch Status : 6400/50000 (13%) | Loss : 2.601732
# Train Epoch : 3 | Batch Status : 9600/50000 (19%) | Loss : 2.727350
# Train Epoch : 3 | Batch Status : 12800/50000 (26%) | Loss : 2.143194
# Train Epoch : 3 | Batch Status : 16000/50000 (32%) | Loss : 1.826247
# Train Epoch : 3 | Batch Status : 19200/50000 (38%) | Loss : 2.415717
# Train Epoch : 3 | Batch Status : 22400/50000 (45%) | Loss : 2.186874
# Train Epoch : 3 | Batch Status : 25600/50000 (51%) | Loss : 2.389803
# Train Epoch : 3 | Batch Status : 28800/50000 (58%) | Loss : 2.164248
# Train Epoch : 3 | Batch Status : 32000/50000 (64%) | Loss : 2.137836
# Train Epoch : 3 | Batch Status : 35200/50000 (70%) | Loss : 2.106300
# Train Epoch : 3 | Batch Status : 38400/50000 (77%) | Loss : 1.713542
# Train Epoch : 3 | Batch Status : 41600/50000 (83%) | Loss : 2.240291
# Train Epoch : 3 | Batch Status : 44800/50000 (90%) | Loss : 2.201849
# Train Epoch : 3 | Batch Status : 48000/50000 (96%) | Loss : 2.180033
# ============================================
# Test set: Average loss : 0.0594, Accuracy : 4886/10000(49%)
# Train Epoch : 4 | Batch Status : 0/50000 (0%) | Loss : 1.653846
# Train Epoch : 4 | Batch Status : 3200/50000 (6%) | Loss : 2.155854
# Train Epoch : 4 | Batch Status : 6400/50000 (13%) | Loss : 1.923104
# Train Epoch : 4 | Batch Status : 9600/50000 (19%) | Loss : 1.384339
# Train Epoch : 4 | Batch Status : 12800/50000 (26%) | Loss : 2.021364
# Train Epoch : 4 | Batch Status : 16000/50000 (32%) | Loss : 1.626992
# Train Epoch : 4 | Batch Status : 19200/50000 (38%) | Loss : 1.934981
# Train Epoch : 4 | Batch Status : 22400/50000 (45%) | Loss : 1.869651
# Train Epoch : 4 | Batch Status : 25600/50000 (51%) | Loss : 1.536568
# Train Epoch : 4 | Batch Status : 28800/50000 (58%) | Loss : 1.390639
# Train Epoch : 4 | Batch Status : 32000/50000 (64%) | Loss : 2.682790
# Train Epoch : 4 | Batch Status : 35200/50000 (70%) | Loss : 1.753117
# Train Epoch : 4 | Batch Status : 38400/50000 (77%) | Loss : 1.676612
# Train Epoch : 4 | Batch Status : 41600/50000 (83%) | Loss : 1.648868
# Train Epoch : 4 | Batch Status : 44800/50000 (90%) | Loss : 1.890651
# Train Epoch : 4 | Batch Status : 48000/50000 (96%) | Loss : 1.986216
# ============================================
# Test set: Average loss : 0.0558, Accuracy : 5081/10000(51%)
# Train Epoch : 5 | Batch Status : 0/50000 (0%) | Loss : 1.571007
# Train Epoch : 5 | Batch Status : 3200/50000 (6%) | Loss : 1.732741
# Train Epoch : 5 | Batch Status : 6400/50000 (13%) | Loss : 1.589242
# Train Epoch : 5 | Batch Status : 9600/50000 (19%) | Loss : 2.188511
# Train Epoch : 5 | Batch Status : 12800/50000 (26%) | Loss : 1.705122
# Train Epoch : 5 | Batch Status : 16000/50000 (32%) | Loss : 1.600892
# Train Epoch : 5 | Batch Status : 19200/50000 (38%) | Loss : 1.479426
# Train Epoch : 5 | Batch Status : 22400/50000 (45%) | Loss : 1.842821
# Train Epoch : 5 | Batch Status : 25600/50000 (51%) | Loss : 1.537695
# Train Epoch : 5 | Batch Status : 28800/50000 (58%) | Loss : 1.656968
# Train Epoch : 5 | Batch Status : 32000/50000 (64%) | Loss : 1.793238
# Train Epoch : 5 | Batch Status : 35200/50000 (70%) | Loss : 2.139232
# Train Epoch : 5 | Batch Status : 38400/50000 (77%) | Loss : 1.725017
# Train Epoch : 5 | Batch Status : 41600/50000 (83%) | Loss : 1.085498
# Train Epoch : 5 | Batch Status : 44800/50000 (90%) | Loss : 1.246766
# Train Epoch : 5 | Batch Status : 48000/50000 (96%) | Loss : 1.531481
# ============================================
# Test set: Average loss : 0.0527, Accuracy : 5349/10000(53%)
# Train Epoch : 6 | Batch Status : 0/50000 (0%) | Loss : 1.544369
# Train Epoch : 6 | Batch Status : 3200/50000 (6%) | Loss : 1.356248
# Train Epoch : 6 | Batch Status : 6400/50000 (13%) | Loss : 1.542498
# Train Epoch : 6 | Batch Status : 9600/50000 (19%) | Loss : 1.729415
# Train Epoch : 6 | Batch Status : 12800/50000 (26%) | Loss : 1.572454
# Train Epoch : 6 | Batch Status : 16000/50000 (32%) | Loss : 1.420866
# Train Epoch : 6 | Batch Status : 19200/50000 (38%) | Loss : 1.429573
# Train Epoch : 6 | Batch Status : 22400/50000 (45%) | Loss : 1.437135
# Train Epoch : 6 | Batch Status : 25600/50000 (51%) | Loss : 1.309526
# Train Epoch : 6 | Batch Status : 28800/50000 (58%) | Loss : 1.491414
# Train Epoch : 6 | Batch Status : 32000/50000 (64%) | Loss : 1.275463
# Train Epoch : 6 | Batch Status : 35200/50000 (70%) | Loss : 1.654449
# Train Epoch : 6 | Batch Status : 38400/50000 (77%) | Loss : 0.968095
# Train Epoch : 6 | Batch Status : 41600/50000 (83%) | Loss : 1.382349
# Train Epoch : 6 | Batch Status : 44800/50000 (90%) | Loss : 2.046271
# Train Epoch : 6 | Batch Status : 48000/50000 (96%) | Loss : 1.368152
# ============================================
# Test set: Average loss : 0.0509, Accuracy : 5489/10000(55%)
# Train Epoch : 7 | Batch Status : 0/50000 (0%) | Loss : 1.370768
# Train Epoch : 7 | Batch Status : 3200/50000 (6%) | Loss : 1.020199
# Train Epoch : 7 | Batch Status : 6400/50000 (13%) | Loss : 1.568305
# Train Epoch : 7 | Batch Status : 9600/50000 (19%) | Loss : 1.845225
# Train Epoch : 7 | Batch Status : 12800/50000 (26%) | Loss : 1.436377
# Train Epoch : 7 | Batch Status : 16000/50000 (32%) | Loss : 1.723954
# Train Epoch : 7 | Batch Status : 19200/50000 (38%) | Loss : 1.371287
# Train Epoch : 7 | Batch Status : 22400/50000 (45%) | Loss : 1.871756
# Train Epoch : 7 | Batch Status : 25600/50000 (51%) | Loss : 1.356531
# Train Epoch : 7 | Batch Status : 28800/50000 (58%) | Loss : 1.057452
# Train Epoch : 7 | Batch Status : 32000/50000 (64%) | Loss : 1.079264
# Train Epoch : 7 | Batch Status : 35200/50000 (70%) | Loss : 1.331202
# Train Epoch : 7 | Batch Status : 38400/50000 (77%) | Loss : 1.457682
# Train Epoch : 7 | Batch Status : 41600/50000 (83%) | Loss : 1.792819
# Train Epoch : 7 | Batch Status : 44800/50000 (90%) | Loss : 1.337642
# Train Epoch : 7 | Batch Status : 48000/50000 (96%) | Loss : 0.998532
# ============================================
# Test set: Average loss : 0.0505, Accuracy : 5548/10000(55%)
# Train Epoch : 8 | Batch Status : 0/50000 (0%) | Loss : 1.547179
# Train Epoch : 8 | Batch Status : 3200/50000 (6%) | Loss : 0.840464
# Train Epoch : 8 | Batch Status : 6400/50000 (13%) | Loss : 1.132059
# Train Epoch : 8 | Batch Status : 9600/50000 (19%) | Loss : 1.702959
# Train Epoch : 8 | Batch Status : 12800/50000 (26%) | Loss : 1.768284
# Train Epoch : 8 | Batch Status : 16000/50000 (32%) | Loss : 1.541557
# Train Epoch : 8 | Batch Status : 19200/50000 (38%) | Loss : 2.030403
# Train Epoch : 8 | Batch Status : 22400/50000 (45%) | Loss : 1.267378
# Train Epoch : 8 | Batch Status : 25600/50000 (51%) | Loss : 1.300959
# Train Epoch : 8 | Batch Status : 28800/50000 (58%) | Loss : 1.610933
# Train Epoch : 8 | Batch Status : 32000/50000 (64%) | Loss : 1.482877
# Train Epoch : 8 | Batch Status : 35200/50000 (70%) | Loss : 1.778657
# Train Epoch : 8 | Batch Status : 38400/50000 (77%) | Loss : 1.469939
# Train Epoch : 8 | Batch Status : 41600/50000 (83%) | Loss : 1.047942
# Train Epoch : 8 | Batch Status : 44800/50000 (90%) | Loss : 1.428062
# Train Epoch : 8 | Batch Status : 48000/50000 (96%) | Loss : 1.382387
# ============================================
# Test set: Average loss : 0.0500, Accuracy : 5638/10000(56%)
# Train Epoch : 9 | Batch Status : 0/50000 (0%) | Loss : 1.272271
# Train Epoch : 9 | Batch Status : 3200/50000 (6%) | Loss : 1.606712
# Train Epoch : 9 | Batch Status : 6400/50000 (13%) | Loss : 1.352403
# Train Epoch : 9 | Batch Status : 9600/50000 (19%) | Loss : 1.714658
# Train Epoch : 9 | Batch Status : 12800/50000 (26%) | Loss : 1.252985
# Train Epoch : 9 | Batch Status : 16000/50000 (32%) | Loss : 1.198431
# Train Epoch : 9 | Batch Status : 19200/50000 (38%) | Loss : 1.178228
# Train Epoch : 9 | Batch Status : 22400/50000 (45%) | Loss : 1.170879
# Train Epoch : 9 | Batch Status : 25600/50000 (51%) | Loss : 1.428015
# Train Epoch : 9 | Batch Status : 28800/50000 (58%) | Loss : 1.008808
# Train Epoch : 9 | Batch Status : 32000/50000 (64%) | Loss : 1.266061
# Train Epoch : 9 | Batch Status : 35200/50000 (70%) | Loss : 1.213516
# Train Epoch : 9 | Batch Status : 38400/50000 (77%) | Loss : 1.204197
# Train Epoch : 9 | Batch Status : 41600/50000 (83%) | Loss : 1.131973
# Train Epoch : 9 | Batch Status : 44800/50000 (90%) | Loss : 1.047195
# Train Epoch : 9 | Batch Status : 48000/50000 (96%) | Loss : 1.071159
# ============================================
# Test set: Average loss : 0.0491, Accuracy : 5727/10000(57%)
# Train Epoch : 10 | Batch Status : 0/50000 (0%) | Loss : 0.541878
# Train Epoch : 10 | Batch Status : 3200/50000 (6%) | Loss : 0.796125
# Train Epoch : 10 | Batch Status : 6400/50000 (13%) | Loss : 1.573146
# Train Epoch : 10 | Batch Status : 9600/50000 (19%) | Loss : 0.982164
# Train Epoch : 10 | Batch Status : 12800/50000 (26%) | Loss : 0.965877
# Train Epoch : 10 | Batch Status : 16000/50000 (32%) | Loss : 1.263749
# Train Epoch : 10 | Batch Status : 19200/50000 (38%) | Loss : 1.158760
# Train Epoch : 10 | Batch Status : 22400/50000 (45%) | Loss : 0.729922
# Train Epoch : 10 | Batch Status : 25600/50000 (51%) | Loss : 0.943722
# Train Epoch : 10 | Batch Status : 28800/50000 (58%) | Loss : 1.250924
# Train Epoch : 10 | Batch Status : 32000/50000 (64%) | Loss : 1.106002
# Train Epoch : 10 | Batch Status : 35200/50000 (70%) | Loss : 1.235619
# Train Epoch : 10 | Batch Status : 38400/50000 (77%) | Loss : 1.603949
# Train Epoch : 10 | Batch Status : 41600/50000 (83%) | Loss : 1.047926
# Train Epoch : 10 | Batch Status : 44800/50000 (90%) | Loss : 1.412562
# Train Epoch : 10 | Batch Status : 48000/50000 (96%) | Loss : 1.248367
# ============================================
# Test set: Average loss : 0.0492, Accuracy : 5696/10000(57%)
# Train Epoch : 11 | Batch Status : 0/50000 (0%) | Loss : 0.928574
# Train Epoch : 11 | Batch Status : 3200/50000 (6%) | Loss : 0.879913
# Train Epoch : 11 | Batch Status : 6400/50000 (13%) | Loss : 1.325236
# Train Epoch : 11 | Batch Status : 9600/50000 (19%) | Loss : 0.860339
# Train Epoch : 11 | Batch Status : 12800/50000 (26%) | Loss : 1.085327
# Train Epoch : 11 | Batch Status : 16000/50000 (32%) | Loss : 0.703839
# Train Epoch : 11 | Batch Status : 19200/50000 (38%) | Loss : 0.904472
# Train Epoch : 11 | Batch Status : 22400/50000 (45%) | Loss : 1.097128
# Train Epoch : 11 | Batch Status : 25600/50000 (51%) | Loss : 0.739840
# Train Epoch : 11 | Batch Status : 28800/50000 (58%) | Loss : 1.098113
# Train Epoch : 11 | Batch Status : 32000/50000 (64%) | Loss : 0.568515
# Train Epoch : 11 | Batch Status : 35200/50000 (70%) | Loss : 1.027031
# Train Epoch : 11 | Batch Status : 38400/50000 (77%) | Loss : 1.504419
# Train Epoch : 11 | Batch Status : 41600/50000 (83%) | Loss : 1.230295
# Train Epoch : 11 | Batch Status : 44800/50000 (90%) | Loss : 1.554715
# Train Epoch : 11 | Batch Status : 48000/50000 (96%) | Loss : 1.579021
# ============================================
# Test set: Average loss : 0.0485, Accuracy : 5770/10000(58%)
# Train Epoch : 12 | Batch Status : 0/50000 (0%) | Loss : 0.738841
# Train Epoch : 12 | Batch Status : 3200/50000 (6%) | Loss : 0.875292
# Train Epoch : 12 | Batch Status : 6400/50000 (13%) | Loss : 1.064415
# Train Epoch : 12 | Batch Status : 9600/50000 (19%) | Loss : 1.080428
# Train Epoch : 12 | Batch Status : 12800/50000 (26%) | Loss : 1.320746
# Train Epoch : 12 | Batch Status : 16000/50000 (32%) | Loss : 1.267646
# Train Epoch : 12 | Batch Status : 19200/50000 (38%) | Loss : 1.719735
# Train Epoch : 12 | Batch Status : 22400/50000 (45%) | Loss : 0.512102
# Train Epoch : 12 | Batch Status : 25600/50000 (51%) | Loss : 1.205222
# Train Epoch : 12 | Batch Status : 28800/50000 (58%) | Loss : 0.770427
# Train Epoch : 12 | Batch Status : 32000/50000 (64%) | Loss : 0.799136
# Train Epoch : 12 | Batch Status : 35200/50000 (70%) | Loss : 0.773720
# Train Epoch : 12 | Batch Status : 38400/50000 (77%) | Loss : 1.450758
# Train Epoch : 12 | Batch Status : 41600/50000 (83%) | Loss : 1.097485
# Train Epoch : 12 | Batch Status : 44800/50000 (90%) | Loss : 1.142125
# Train Epoch : 12 | Batch Status : 48000/50000 (96%) | Loss : 0.878316
# ============================================
# Test set: Average loss : 0.0489, Accuracy : 5823/10000(58%)
# Train Epoch : 13 | Batch Status : 0/50000 (0%) | Loss : 0.883617
# Train Epoch : 13 | Batch Status : 3200/50000 (6%) | Loss : 0.824710
# Train Epoch : 13 | Batch Status : 6400/50000 (13%) | Loss : 0.877283
# Train Epoch : 13 | Batch Status : 9600/50000 (19%) | Loss : 0.748862
# Train Epoch : 13 | Batch Status : 12800/50000 (26%) | Loss : 0.669697
# Train Epoch : 13 | Batch Status : 16000/50000 (32%) | Loss : 0.905179
# Train Epoch : 13 | Batch Status : 19200/50000 (38%) | Loss : 0.934301
# Train Epoch : 13 | Batch Status : 22400/50000 (45%) | Loss : 1.386839
# Train Epoch : 13 | Batch Status : 25600/50000 (51%) | Loss : 1.181021
# Train Epoch : 13 | Batch Status : 28800/50000 (58%) | Loss : 1.149827
# Train Epoch : 13 | Batch Status : 32000/50000 (64%) | Loss : 0.616896
# Train Epoch : 13 | Batch Status : 35200/50000 (70%) | Loss : 0.821111
# Train Epoch : 13 | Batch Status : 38400/50000 (77%) | Loss : 0.983131
# Train Epoch : 13 | Batch Status : 41600/50000 (83%) | Loss : 0.557080
# Train Epoch : 13 | Batch Status : 44800/50000 (90%) | Loss : 0.924551
# Train Epoch : 13 | Batch Status : 48000/50000 (96%) | Loss : 1.473310
# ============================================
# Test set: Average loss : 0.0487, Accuracy : 5885/10000(59%)
# Train Epoch : 14 | Batch Status : 0/50000 (0%) | Loss : 1.074941
# Train Epoch : 14 | Batch Status : 3200/50000 (6%) | Loss : 0.955351
# Train Epoch : 14 | Batch Status : 6400/50000 (13%) | Loss : 1.102062
# Train Epoch : 14 | Batch Status : 9600/50000 (19%) | Loss : 0.578211
# Train Epoch : 14 | Batch Status : 12800/50000 (26%) | Loss : 1.007546
# Train Epoch : 14 | Batch Status : 16000/50000 (32%) | Loss : 0.926937
# Train Epoch : 14 | Batch Status : 19200/50000 (38%) | Loss : 0.945653
# Train Epoch : 14 | Batch Status : 22400/50000 (45%) | Loss : 1.069162
# Train Epoch : 14 | Batch Status : 25600/50000 (51%) | Loss : 0.738189
# Train Epoch : 14 | Batch Status : 28800/50000 (58%) | Loss : 1.461494
# Train Epoch : 14 | Batch Status : 32000/50000 (64%) | Loss : 1.342012
# Train Epoch : 14 | Batch Status : 35200/50000 (70%) | Loss : 0.583677
# Train Epoch : 14 | Batch Status : 38400/50000 (77%) | Loss : 0.859922
# Train Epoch : 14 | Batch Status : 41600/50000 (83%) | Loss : 0.755762
# Train Epoch : 14 | Batch Status : 44800/50000 (90%) | Loss : 1.117039
# Train Epoch : 14 | Batch Status : 48000/50000 (96%) | Loss : 1.071968
# ============================================
# Test set: Average loss : 0.0490, Accuracy : 5865/10000(59%)
# Train Epoch : 15 | Batch Status : 0/50000 (0%) | Loss : 0.710954
# Train Epoch : 15 | Batch Status : 3200/50000 (6%) | Loss : 1.041534
# Train Epoch : 15 | Batch Status : 6400/50000 (13%) | Loss : 1.235477
# Train Epoch : 15 | Batch Status : 9600/50000 (19%) | Loss : 0.963579
# Train Epoch : 15 | Batch Status : 12800/50000 (26%) | Loss : 0.424548
# Train Epoch : 15 | Batch Status : 16000/50000 (32%) | Loss : 0.966148
# Train Epoch : 15 | Batch Status : 19200/50000 (38%) | Loss : 0.950031
# Train Epoch : 15 | Batch Status : 22400/50000 (45%) | Loss : 0.884227
# Train Epoch : 15 | Batch Status : 25600/50000 (51%) | Loss : 0.811076
# Train Epoch : 15 | Batch Status : 28800/50000 (58%) | Loss : 1.087955
# Train Epoch : 15 | Batch Status : 32000/50000 (64%) | Loss : 0.701042
# Train Epoch : 15 | Batch Status : 35200/50000 (70%) | Loss : 0.737828
# Train Epoch : 15 | Batch Status : 38400/50000 (77%) | Loss : 0.918339
# Train Epoch : 15 | Batch Status : 41600/50000 (83%) | Loss : 1.061069
# Train Epoch : 15 | Batch Status : 44800/50000 (90%) | Loss : 0.580952
# Train Epoch : 15 | Batch Status : 48000/50000 (96%) | Loss : 0.688807
# ============================================
# Test set: Average loss : 0.0499, Accuracy : 5820/10000(58%)
# Train Epoch : 16 | Batch Status : 0/50000 (0%) | Loss : 0.713382
# Train Epoch : 16 | Batch Status : 3200/50000 (6%) | Loss : 0.768534
# Train Epoch : 16 | Batch Status : 6400/50000 (13%) | Loss : 0.604155
# Train Epoch : 16 | Batch Status : 9600/50000 (19%) | Loss : 0.754647
# Train Epoch : 16 | Batch Status : 12800/50000 (26%) | Loss : 1.148421
# Train Epoch : 16 | Batch Status : 16000/50000 (32%) | Loss : 0.780503
# Train Epoch : 16 | Batch Status : 19200/50000 (38%) | Loss : 0.456984
# Train Epoch : 16 | Batch Status : 22400/50000 (45%) | Loss : 0.579201
# Train Epoch : 16 | Batch Status : 25600/50000 (51%) | Loss : 0.936587
# Train Epoch : 16 | Batch Status : 28800/50000 (58%) | Loss : 0.619624
# Train Epoch : 16 | Batch Status : 32000/50000 (64%) | Loss : 0.874024
# Train Epoch : 16 | Batch Status : 35200/50000 (70%) | Loss : 0.959100
# Train Epoch : 16 | Batch Status : 38400/50000 (77%) | Loss : 0.854483
# Train Epoch : 16 | Batch Status : 41600/50000 (83%) | Loss : 0.487537
# Train Epoch : 16 | Batch Status : 44800/50000 (90%) | Loss : 0.942317
# Train Epoch : 16 | Batch Status : 48000/50000 (96%) | Loss : 0.604678
# ============================================
# Test set: Average loss : 0.0503, Accuracy : 5849/10000(58%)
# Train Epoch : 17 | Batch Status : 0/50000 (0%) | Loss : 0.499428
# Train Epoch : 17 | Batch Status : 3200/50000 (6%) | Loss : 1.073751
# Train Epoch : 17 | Batch Status : 6400/50000 (13%) | Loss : 0.400485
# Train Epoch : 17 | Batch Status : 9600/50000 (19%) | Loss : 1.088689
# Train Epoch : 17 | Batch Status : 12800/50000 (26%) | Loss : 0.730585
# Train Epoch : 17 | Batch Status : 16000/50000 (32%) | Loss : 0.891744
# Train Epoch : 17 | Batch Status : 19200/50000 (38%) | Loss : 1.236819
# Train Epoch : 17 | Batch Status : 22400/50000 (45%) | Loss : 0.454507
# Train Epoch : 17 | Batch Status : 25600/50000 (51%) | Loss : 0.701822
# Train Epoch : 17 | Batch Status : 28800/50000 (58%) | Loss : 0.893745
# Train Epoch : 17 | Batch Status : 32000/50000 (64%) | Loss : 0.763962
# Train Epoch : 17 | Batch Status : 35200/50000 (70%) | Loss : 1.015109
# Train Epoch : 17 | Batch Status : 38400/50000 (77%) | Loss : 0.658229
# Train Epoch : 17 | Batch Status : 41600/50000 (83%) | Loss : 1.432759
# Train Epoch : 17 | Batch Status : 44800/50000 (90%) | Loss : 0.912906
# Train Epoch : 17 | Batch Status : 48000/50000 (96%) | Loss : 0.834264
# ============================================
# Test set: Average loss : 0.0508, Accuracy : 5886/10000(59%)
# Train Epoch : 18 | Batch Status : 0/50000 (0%) | Loss : 0.496273
# Train Epoch : 18 | Batch Status : 3200/50000 (6%) | Loss : 0.488451
# Train Epoch : 18 | Batch Status : 6400/50000 (13%) | Loss : 0.483946
# Train Epoch : 18 | Batch Status : 9600/50000 (19%) | Loss : 0.903059
# Train Epoch : 18 | Batch Status : 12800/50000 (26%) | Loss : 0.843416
# Train Epoch : 18 | Batch Status : 16000/50000 (32%) | Loss : 0.793348
# Train Epoch : 18 | Batch Status : 19200/50000 (38%) | Loss : 0.995198
# Train Epoch : 18 | Batch Status : 22400/50000 (45%) | Loss : 0.615080
# Train Epoch : 18 | Batch Status : 25600/50000 (51%) | Loss : 0.492400
# Train Epoch : 18 | Batch Status : 28800/50000 (58%) | Loss : 0.384488
# Train Epoch : 18 | Batch Status : 32000/50000 (64%) | Loss : 0.744151
# Train Epoch : 18 | Batch Status : 35200/50000 (70%) | Loss : 0.995653
# Train Epoch : 18 | Batch Status : 38400/50000 (77%) | Loss : 1.206163
# Train Epoch : 18 | Batch Status : 41600/50000 (83%) | Loss : 0.852920
# Train Epoch : 18 | Batch Status : 44800/50000 (90%) | Loss : 0.729504
# Train Epoch : 18 | Batch Status : 48000/50000 (96%) | Loss : 0.961981
# ============================================
# Test set: Average loss : 0.0514, Accuracy : 5857/10000(59%)
# Train Epoch : 19 | Batch Status : 0/50000 (0%) | Loss : 0.503859
# Train Epoch : 19 | Batch Status : 3200/50000 (6%) | Loss : 0.490159
# Train Epoch : 19 | Batch Status : 6400/50000 (13%) | Loss : 0.749361
# Train Epoch : 19 | Batch Status : 9600/50000 (19%) | Loss : 0.970515
# Train Epoch : 19 | Batch Status : 12800/50000 (26%) | Loss : 0.443639
# Train Epoch : 19 | Batch Status : 16000/50000 (32%) | Loss : 0.949458
# Train Epoch : 19 | Batch Status : 19200/50000 (38%) | Loss : 0.680877
# Train Epoch : 19 | Batch Status : 22400/50000 (45%) | Loss : 0.568688
# Train Epoch : 19 | Batch Status : 25600/50000 (51%) | Loss : 0.714398
# Train Epoch : 19 | Batch Status : 28800/50000 (58%) | Loss : 0.845573
# Train Epoch : 19 | Batch Status : 32000/50000 (64%) | Loss : 0.435905
# Train Epoch : 19 | Batch Status : 35200/50000 (70%) | Loss : 0.874268
# Train Epoch : 19 | Batch Status : 38400/50000 (77%) | Loss : 0.730750
# Train Epoch : 19 | Batch Status : 41600/50000 (83%) | Loss : 0.576535
# Train Epoch : 19 | Batch Status : 44800/50000 (90%) | Loss : 0.662027
# Train Epoch : 19 | Batch Status : 48000/50000 (96%) | Loss : 0.286123
# ============================================
# Test set: Average loss : 0.0521, Accuracy : 5896/10000(59%)
# Train Epoch : 20 | Batch Status : 0/50000 (0%) | Loss : 0.608597
# Train Epoch : 20 | Batch Status : 3200/50000 (6%) | Loss : 0.632607
# Train Epoch : 20 | Batch Status : 6400/50000 (13%) | Loss : 0.353979
# Train Epoch : 20 | Batch Status : 9600/50000 (19%) | Loss : 0.397771
# Train Epoch : 20 | Batch Status : 12800/50000 (26%) | Loss : 0.498894
# Train Epoch : 20 | Batch Status : 16000/50000 (32%) | Loss : 0.718804
# Train Epoch : 20 | Batch Status : 19200/50000 (38%) | Loss : 0.480050
# Train Epoch : 20 | Batch Status : 22400/50000 (45%) | Loss : 0.713413
# Train Epoch : 20 | Batch Status : 25600/50000 (51%) | Loss : 0.644226
# Train Epoch : 20 | Batch Status : 28800/50000 (58%) | Loss : 0.750341
# Train Epoch : 20 | Batch Status : 32000/50000 (64%) | Loss : 1.043913
# Train Epoch : 20 | Batch Status : 35200/50000 (70%) | Loss : 0.596932
# Train Epoch : 20 | Batch Status : 38400/50000 (77%) | Loss : 0.492175
# Train Epoch : 20 | Batch Status : 41600/50000 (83%) | Loss : 0.607412
# Train Epoch : 20 | Batch Status : 44800/50000 (90%) | Loss : 0.569011
# Train Epoch : 20 | Batch Status : 48000/50000 (96%) | Loss : 1.031063
# ============================================
# Test set: Average loss : 0.0521, Accuracy : 5887/10000(59%)
# Train Epoch : 21 | Batch Status : 0/50000 (0%) | Loss : 0.551895
# Train Epoch : 21 | Batch Status : 3200/50000 (6%) | Loss : 0.618921
# Train Epoch : 21 | Batch Status : 6400/50000 (13%) | Loss : 0.534176
# Train Epoch : 21 | Batch Status : 9600/50000 (19%) | Loss : 0.764064
# Train Epoch : 21 | Batch Status : 12800/50000 (26%) | Loss : 0.919752
# Train Epoch : 21 | Batch Status : 16000/50000 (32%) | Loss : 0.641149
# Train Epoch : 21 | Batch Status : 19200/50000 (38%) | Loss : 0.538778
# Train Epoch : 21 | Batch Status : 22400/50000 (45%) | Loss : 0.497959
# Train Epoch : 21 | Batch Status : 25600/50000 (51%) | Loss : 0.512312
# Train Epoch : 21 | Batch Status : 28800/50000 (58%) | Loss : 0.514415
# Train Epoch : 21 | Batch Status : 32000/50000 (64%) | Loss : 0.693704
# Train Epoch : 21 | Batch Status : 35200/50000 (70%) | Loss : 0.447700
# Train Epoch : 21 | Batch Status : 38400/50000 (77%) | Loss : 0.814865
# Train Epoch : 21 | Batch Status : 41600/50000 (83%) | Loss : 0.661046
# Train Epoch : 21 | Batch Status : 44800/50000 (90%) | Loss : 0.779322
# Train Epoch : 21 | Batch Status : 48000/50000 (96%) | Loss : 0.359775
# ============================================
# Test set: Average loss : 0.0510, Accuracy : 5958/10000(60%)
# Train Epoch : 22 | Batch Status : 0/50000 (0%) | Loss : 0.701420
# Train Epoch : 22 | Batch Status : 3200/50000 (6%) | Loss : 0.578750
# Train Epoch : 22 | Batch Status : 6400/50000 (13%) | Loss : 0.352079
# Train Epoch : 22 | Batch Status : 9600/50000 (19%) | Loss : 0.565148
# Train Epoch : 22 | Batch Status : 12800/50000 (26%) | Loss : 0.708596
# Train Epoch : 22 | Batch Status : 16000/50000 (32%) | Loss : 0.774485
# Train Epoch : 22 | Batch Status : 19200/50000 (38%) | Loss : 0.688523
# Train Epoch : 22 | Batch Status : 22400/50000 (45%) | Loss : 1.010030
# Train Epoch : 22 | Batch Status : 25600/50000 (51%) | Loss : 0.612952
# Train Epoch : 22 | Batch Status : 28800/50000 (58%) | Loss : 0.727671
# Train Epoch : 22 | Batch Status : 32000/50000 (64%) | Loss : 0.598445
# Train Epoch : 22 | Batch Status : 35200/50000 (70%) | Loss : 0.487637
# Train Epoch : 22 | Batch Status : 38400/50000 (77%) | Loss : 0.863181
# Train Epoch : 22 | Batch Status : 41600/50000 (83%) | Loss : 0.667649
# Train Epoch : 22 | Batch Status : 44800/50000 (90%) | Loss : 0.672910
# Train Epoch : 22 | Batch Status : 48000/50000 (96%) | Loss : 0.802662
# ============================================
# Test set: Average loss : 0.0523, Accuracy : 5905/10000(59%)
# Train Epoch : 23 | Batch Status : 0/50000 (0%) | Loss : 0.559807
# Train Epoch : 23 | Batch Status : 3200/50000 (6%) | Loss : 0.444415
# Train Epoch : 23 | Batch Status : 6400/50000 (13%) | Loss : 0.752702
# Train Epoch : 23 | Batch Status : 9600/50000 (19%) | Loss : 0.588156
# Train Epoch : 23 | Batch Status : 12800/50000 (26%) | Loss : 0.497590
# Train Epoch : 23 | Batch Status : 16000/50000 (32%) | Loss : 0.573119
# Train Epoch : 23 | Batch Status : 19200/50000 (38%) | Loss : 0.707548
# Train Epoch : 23 | Batch Status : 22400/50000 (45%) | Loss : 0.741843
# Train Epoch : 23 | Batch Status : 25600/50000 (51%) | Loss : 0.908139
# Train Epoch : 23 | Batch Status : 28800/50000 (58%) | Loss : 0.620002
# Train Epoch : 23 | Batch Status : 32000/50000 (64%) | Loss : 0.486776
# Train Epoch : 23 | Batch Status : 35200/50000 (70%) | Loss : 0.687022
# Train Epoch : 23 | Batch Status : 38400/50000 (77%) | Loss : 0.656660
# Train Epoch : 23 | Batch Status : 41600/50000 (83%) | Loss : 0.494886
# Train Epoch : 23 | Batch Status : 44800/50000 (90%) | Loss : 0.395552
# Train Epoch : 23 | Batch Status : 48000/50000 (96%) | Loss : 0.828813
# ============================================
# Test set: Average loss : 0.0538, Accuracy : 5919/10000(59%)
# Train Epoch : 24 | Batch Status : 0/50000 (0%) | Loss : 0.252970
# Train Epoch : 24 | Batch Status : 3200/50000 (6%) | Loss : 0.620852
# Train Epoch : 24 | Batch Status : 6400/50000 (13%) | Loss : 0.611700
# Train Epoch : 24 | Batch Status : 9600/50000 (19%) | Loss : 0.398658
# Train Epoch : 24 | Batch Status : 12800/50000 (26%) | Loss : 0.397906
# Train Epoch : 24 | Batch Status : 16000/50000 (32%) | Loss : 0.336658
# Train Epoch : 24 | Batch Status : 19200/50000 (38%) | Loss : 0.397857
# Train Epoch : 24 | Batch Status : 22400/50000 (45%) | Loss : 0.498959
# Train Epoch : 24 | Batch Status : 25600/50000 (51%) | Loss : 0.686363
# Train Epoch : 24 | Batch Status : 28800/50000 (58%) | Loss : 0.517489
# Train Epoch : 24 | Batch Status : 32000/50000 (64%) | Loss : 0.244701
# Train Epoch : 24 | Batch Status : 35200/50000 (70%) | Loss : 1.173569
# Train Epoch : 24 | Batch Status : 38400/50000 (77%) | Loss : 0.713387
# Train Epoch : 24 | Batch Status : 41600/50000 (83%) | Loss : 0.392191
# Train Epoch : 24 | Batch Status : 44800/50000 (90%) | Loss : 0.530456
# Train Epoch : 24 | Batch Status : 48000/50000 (96%) | Loss : 0.679191
# ============================================
# Test set: Average loss : 0.0539, Accuracy : 5904/10000(59%)
# Train Epoch : 25 | Batch Status : 0/50000 (0%) | Loss : 0.358002
# Train Epoch : 25 | Batch Status : 3200/50000 (6%) | Loss : 0.771587
# Train Epoch : 25 | Batch Status : 6400/50000 (13%) | Loss : 0.505783
# Train Epoch : 25 | Batch Status : 9600/50000 (19%) | Loss : 0.581040
# Train Epoch : 25 | Batch Status : 12800/50000 (26%) | Loss : 0.666336
# Train Epoch : 25 | Batch Status : 16000/50000 (32%) | Loss : 0.344067
# Train Epoch : 25 | Batch Status : 19200/50000 (38%) | Loss : 0.423152
# Train Epoch : 25 | Batch Status : 22400/50000 (45%) | Loss : 0.964181
# Train Epoch : 25 | Batch Status : 25600/50000 (51%) | Loss : 0.890746
# Train Epoch : 25 | Batch Status : 28800/50000 (58%) | Loss : 0.445946
# Train Epoch : 25 | Batch Status : 32000/50000 (64%) | Loss : 0.263190
# Train Epoch : 25 | Batch Status : 35200/50000 (70%) | Loss : 0.345563
# Train Epoch : 25 | Batch Status : 38400/50000 (77%) | Loss : 0.719727
# Train Epoch : 25 | Batch Status : 41600/50000 (83%) | Loss : 0.343121
# Train Epoch : 25 | Batch Status : 44800/50000 (90%) | Loss : 0.708644
# Train Epoch : 25 | Batch Status : 48000/50000 (96%) | Loss : 0.457321
# ============================================
# Test set: Average loss : 0.0539, Accuracy : 5879/10000(59%)
# Train Epoch : 26 | Batch Status : 0/50000 (0%) | Loss : 0.477922
# Train Epoch : 26 | Batch Status : 3200/50000 (6%) | Loss : 0.758053
# Train Epoch : 26 | Batch Status : 6400/50000 (13%) | Loss : 0.279496
# Train Epoch : 26 | Batch Status : 9600/50000 (19%) | Loss : 0.520760
# Train Epoch : 26 | Batch Status : 12800/50000 (26%) | Loss : 0.256226
# Train Epoch : 26 | Batch Status : 16000/50000 (32%) | Loss : 0.631648
# Train Epoch : 26 | Batch Status : 19200/50000 (38%) | Loss : 0.698641
# Train Epoch : 26 | Batch Status : 22400/50000 (45%) | Loss : 0.286066
# Train Epoch : 26 | Batch Status : 25600/50000 (51%) | Loss : 0.517906
# Train Epoch : 26 | Batch Status : 28800/50000 (58%) | Loss : 0.315865
# Train Epoch : 26 | Batch Status : 32000/50000 (64%) | Loss : 0.624768
# Train Epoch : 26 | Batch Status : 35200/50000 (70%) | Loss : 0.539926
# Train Epoch : 26 | Batch Status : 38400/50000 (77%) | Loss : 0.331265
# Train Epoch : 26 | Batch Status : 41600/50000 (83%) | Loss : 0.460919
# Train Epoch : 26 | Batch Status : 44800/50000 (90%) | Loss : 0.522571
# Train Epoch : 26 | Batch Status : 48000/50000 (96%) | Loss : 0.454528
# ============================================
# Test set: Average loss : 0.0552, Accuracy : 5896/10000(59%)
# Train Epoch : 27 | Batch Status : 0/50000 (0%) | Loss : 0.399732
# Train Epoch : 27 | Batch Status : 3200/50000 (6%) | Loss : 0.238929
# Train Epoch : 27 | Batch Status : 6400/50000 (13%) | Loss : 0.244932
# Train Epoch : 27 | Batch Status : 9600/50000 (19%) | Loss : 0.145785
# Train Epoch : 27 | Batch Status : 12800/50000 (26%) | Loss : 0.499896
# Train Epoch : 27 | Batch Status : 16000/50000 (32%) | Loss : 0.747864
# Train Epoch : 27 | Batch Status : 19200/50000 (38%) | Loss : 0.272738
# Train Epoch : 27 | Batch Status : 22400/50000 (45%) | Loss : 0.375772
# Train Epoch : 27 | Batch Status : 25600/50000 (51%) | Loss : 0.400351
# Train Epoch : 27 | Batch Status : 28800/50000 (58%) | Loss : 0.383970
# Train Epoch : 27 | Batch Status : 32000/50000 (64%) | Loss : 0.453160
# Train Epoch : 27 | Batch Status : 35200/50000 (70%) | Loss : 0.661958
# Train Epoch : 27 | Batch Status : 38400/50000 (77%) | Loss : 0.491089
# Train Epoch : 27 | Batch Status : 41600/50000 (83%) | Loss : 0.379433
# Train Epoch : 27 | Batch Status : 44800/50000 (90%) | Loss : 0.525431
# Train Epoch : 27 | Batch Status : 48000/50000 (96%) | Loss : 0.292958
# ============================================
# Test set: Average loss : 0.0553, Accuracy : 5854/10000(59%)
# Train Epoch : 28 | Batch Status : 0/50000 (0%) | Loss : 0.380431
# Train Epoch : 28 | Batch Status : 3200/50000 (6%) | Loss : 0.226846
# Train Epoch : 28 | Batch Status : 6400/50000 (13%) | Loss : 0.332215
# Train Epoch : 28 | Batch Status : 9600/50000 (19%) | Loss : 0.136776
# Train Epoch : 28 | Batch Status : 12800/50000 (26%) | Loss : 0.809199
# Train Epoch : 28 | Batch Status : 16000/50000 (32%) | Loss : 0.644094
# Train Epoch : 28 | Batch Status : 19200/50000 (38%) | Loss : 0.244180
# Train Epoch : 28 | Batch Status : 22400/50000 (45%) | Loss : 0.660321
# Train Epoch : 28 | Batch Status : 25600/50000 (51%) | Loss : 0.360845
# Train Epoch : 28 | Batch Status : 28800/50000 (58%) | Loss : 0.571396
# Train Epoch : 28 | Batch Status : 32000/50000 (64%) | Loss : 0.204401
# Train Epoch : 28 | Batch Status : 35200/50000 (70%) | Loss : 0.630526
# Train Epoch : 28 | Batch Status : 38400/50000 (77%) | Loss : 0.313961
# Train Epoch : 28 | Batch Status : 41600/50000 (83%) | Loss : 0.869291
# Train Epoch : 28 | Batch Status : 44800/50000 (90%) | Loss : 0.472520
# Train Epoch : 28 | Batch Status : 48000/50000 (96%) | Loss : 0.440449
# ============================================
# Test set: Average loss : 0.0559, Accuracy : 5930/10000(59%)
# Train Epoch : 29 | Batch Status : 0/50000 (0%) | Loss : 0.356766
# Train Epoch : 29 | Batch Status : 3200/50000 (6%) | Loss : 0.094728
# Train Epoch : 29 | Batch Status : 6400/50000 (13%) | Loss : 0.580374
# Train Epoch : 29 | Batch Status : 9600/50000 (19%) | Loss : 0.578602
# Train Epoch : 29 | Batch Status : 12800/50000 (26%) | Loss : 0.203315
# Train Epoch : 29 | Batch Status : 16000/50000 (32%) | Loss : 0.557506
# Train Epoch : 29 | Batch Status : 19200/50000 (38%) | Loss : 0.193366
# Train Epoch : 29 | Batch Status : 22400/50000 (45%) | Loss : 0.297939
# Train Epoch : 29 | Batch Status : 25600/50000 (51%) | Loss : 0.357882
# Train Epoch : 29 | Batch Status : 28800/50000 (58%) | Loss : 0.583379
# Train Epoch : 29 | Batch Status : 32000/50000 (64%) | Loss : 0.329029
# Train Epoch : 29 | Batch Status : 35200/50000 (70%) | Loss : 0.181782
# Train Epoch : 29 | Batch Status : 38400/50000 (77%) | Loss : 0.215726
# Train Epoch : 29 | Batch Status : 41600/50000 (83%) | Loss : 0.326312
# Train Epoch : 29 | Batch Status : 44800/50000 (90%) | Loss : 0.454327
# Train Epoch : 29 | Batch Status : 48000/50000 (96%) | Loss : 0.414655
# ============================================
# Test set: Average loss : 0.0566, Accuracy : 5911/10000(59%)
# Train Epoch : 30 | Batch Status : 0/50000 (0%) | Loss : 0.377829
# Train Epoch : 30 | Batch Status : 3200/50000 (6%) | Loss : 0.205586
# Train Epoch : 30 | Batch Status : 6400/50000 (13%) | Loss : 0.472349
# Train Epoch : 30 | Batch Status : 9600/50000 (19%) | Loss : 0.339378
# Train Epoch : 30 | Batch Status : 12800/50000 (26%) | Loss : 0.357150
# Train Epoch : 30 | Batch Status : 16000/50000 (32%) | Loss : 0.247542
# Train Epoch : 30 | Batch Status : 19200/50000 (38%) | Loss : 0.389162
# Train Epoch : 30 | Batch Status : 22400/50000 (45%) | Loss : 0.128983
# Train Epoch : 30 | Batch Status : 25600/50000 (51%) | Loss : 0.293355
# Train Epoch : 30 | Batch Status : 28800/50000 (58%) | Loss : 0.278834
# Train Epoch : 30 | Batch Status : 32000/50000 (64%) | Loss : 0.363488
# Train Epoch : 30 | Batch Status : 35200/50000 (70%) | Loss : 0.457872
# Train Epoch : 30 | Batch Status : 38400/50000 (77%) | Loss : 0.407687
# Train Epoch : 30 | Batch Status : 41600/50000 (83%) | Loss : 0.594209
# Train Epoch : 30 | Batch Status : 44800/50000 (90%) | Loss : 0.255040
# Train Epoch : 30 | Batch Status : 48000/50000 (96%) | Loss : 0.603752
# ============================================
# Test set: Average loss : 0.0578, Accuracy : 5936/10000(59%)
